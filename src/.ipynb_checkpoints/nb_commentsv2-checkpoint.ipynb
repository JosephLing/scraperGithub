# %%
from nb_imports import *
# %matplotlib inline
import csvReader
import config
import lib

FIELDS = ["comments", "blank_lines", "code", "config", "yaml_encoding_error", "code_with_comments", "lines", "percentage", "stars", "sub", "data", "id"]
dtypes = {"comments":int, "blank_lines":int, "code":int, "config":str, 
          "yaml_encoding_error":str, "code_with_comments":int, "lines":int, "percentage":float, "stars":int, "sub":int, "data":str, "id":int}
# csvfiledata = csvReader.readfile("yaml threaded.csv", fields=FIELDS)

# %%
df = pd.read_csv("yaml threaded1.csv", dtype=dtypes)

# %%
df.head(5)
# Out:
#    comments  blank_lines  code    config           lang yaml_encoding_error  \
# 0         0            2     9    travis        b'Java'                 NaN
# 1         0            8    50    travis      b'Python'                 NaN
# 2         1            0    19    travis  b'JavaScript'                 NaN
# 3         0            8    28  circleci  b'JavaScript'                 NaN
# 4         0            6   135    travis           b'C'                 NaN
#
#    code_with_comments  lines  percentage  stars  sub  \
# 0                   0     11    0.000000   4039  128
# 1                   1     57    0.000000   4039  118
# 2                   0     19    5.263158   4039  163
# 3                   0     36    0.000000   4039  163
# 4                  36    105    0.000000   4038  233
#
#                                                 data        id
# 0  bGFuZ3VhZ2U6IGphdmEKamRrOiBvcmFjbGVqZGs3CmVudj...  44498352
# 1  ZGlzdDogdHJ1c3R5CgpsYW5ndWFnZTogcHl0aG9uCgpjYW...   2337852
# 2  c3VkbzogZmFsc2UKbGFuZ3VhZ2U6IG5vZGVfanMKb3M6Ci...  66830040
# 3  dmFyXzE6ICZjYWNoZV9rZXkgc2FuLWRlcGVuZGVuY3ktY2...  66830040
# 4  bGFuZ3VhZ2U6IHN3aWZ0Cnhjb2RlX3dvcmtzcGFjZTogUH...  12416862

# %%
df.describe()
# Out:
#           comments  blank_lines         code  code_with_comments        lines  \
# count  6719.000000  6719.000000  6719.000000         6719.000000  6719.000000
# mean      1.218634     5.635214    47.947611            2.107308    51.475517
# std       5.800953     8.913054   116.139377            7.313704   117.472145
# min       0.000000     0.000000     0.000000            0.000000     1.000000
# 25%       0.000000     1.000000    13.000000            0.000000    15.000000
# 50%       0.000000     4.000000    24.000000            0.000000    27.000000
# 75%       0.000000     7.000000    47.000000            1.000000    52.000000
# max     276.000000   281.000000  5617.000000          209.000000  5583.000000
#
#         percentage         stars          sub            id
# count  6719.000000   6719.000000  6719.000000  6.719000e+03
# mean      2.015266   4671.352880   193.271022  4.244331e+07
# std       6.295667   6761.694355   299.199836  4.447869e+07
# min       0.000000   1080.000000     2.000000  2.700000e+01
# 25%       0.000000   1476.000000    55.000000  7.359283e+06
# 50%       0.000000   2620.000000   104.000000  2.694732e+07
# 75%       0.000000   4913.000000   210.000000  6.363980e+07
# max      65.671642  92440.000000  5075.000000  2.205177e+08

# %%
df.sample(1000).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 3686 to 1203
# Data columns (total 13 columns):
# comments               1000 non-null int32
# blank_lines            1000 non-null int32
# code                   1000 non-null int32
# config                 1000 non-null object
# lang                   987 non-null object
# yaml_encoding_error    4 non-null object
# code_with_comments     1000 non-null int32
# lines                  1000 non-null int32
# percentage             1000 non-null float64
# stars                  1000 non-null int32
# sub                    1000 non-null int32
# data                   1000 non-null object
# id                     1000 non-null int32
# dtypes: float64(1), int32(8), object(4)
# memory usage: 78.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6719 entries, 0 to 6718
# Data columns (total 13 columns):
# comments               6719 non-null int32
# blank_lines            6719 non-null int32
# code                   6719 non-null int32
# config                 6719 non-null object
# lang                   6647 non-null object
# yaml_encoding_error    21 non-null object
# code_with_comments     6719 non-null int32
# lines                  6719 non-null int32
# percentage             6719 non-null float64
# stars                  6719 non-null int32
# sub                    6719 non-null int32
# data                   6719 non-null object
# id                     6719 non-null int32
# dtypes: float64(1), int32(8), object(4)
# memory usage: 472.6+ KB

# %%
sns.boxplot(x="comments", data=df.sample(1000))

# %%
sns.boxplot(x="comments",data=df)

# %%
sns.scatterplot(x=df['lines'], y=df['percentage'])

# %%
sns.scatterplot(x=dataset['stars'], y=dataset['percentage'])

# %%
data_reduced = pd.DataFrame(comment_stats_no_zero)
data_reduced.head(5)

# %%
sns.scatterplot(x=data_reduced['lines'], y=data_reduced['percentage'])

# %%
cat = dataset.sort_values(by=['percentage'], ascending=False)
dataset.head(4)

# %%
cat.head(4)

# %%
sns.lineplot(x="stars", y="percentage", data=cat, sort=False)

# %%
sns.lineplot(x="sub", y="percentage", data=cat, sort=False)

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="stars", y="percentage", data=df);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="sub", y="percentage", data=df);

# %% [markdown]
# There is a very minor increase in number of comments per line of yaml configuration for build systems. This is particularly the case in projects which have more subscribers than stars.

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=df);

# %%
from scipy import stats
print(len(df))
_temp = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
print(len(_temp))
_temp.describe()
# Out:
# 6719
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-fe447213fc94> in <module>
#       1 from scipy import stats
#       2 print(len(df))
# ----> 3 _temp = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
#       4 print(len(_temp))
#       5 _temp.describe()
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof)
#    2307     """
#    2308     a = np.asanyarray(a)
# -> 2309     mns = a.mean(axis=axis)
#    2310     sstd = a.std(axis=axis, ddof=ddof)
#    2311     if axis and mns.ndim < a.ndim:
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=df[df.code < 1000]);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="lines", y="blank_lines", data=df[df.lines < 1000]);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="lines", y="blank_lines", data=df[df.lines < 300]);

# %% [markdown]
# There is a very minor increase in number of comments per line of yaml configuration for build systems. This is particularly the case in projects which have more subscribers than stars.

# %%
dataset.describe()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=df);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=df[(df.code< 1200) & (df.comments != 0)]);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=df[df.code
                                            < 1200]);

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="lines", y="blank_lines", data=dataset[(np.abs(stats.zscore(dataset)) < 4).all(axis=1)]);

# %% [markdown]
# # note
#
# Really interesting observation is that the graphs above the y=x line is roughly where the data stops. Therefore its all over the place and it would be good to plot that line to get a better idea of what is happening.
#
# In order to do this use: https://stackoverflow.com/questions/36146684/using-seaborn-how-can-i-draw-a-line-of-my-choice-across-my-scatterplot as a setup.

# %%
sns.distplot(df["comments"], rug=True)

# %%
sns.jointplot(x="comments", y="code", data=df);

# %%
sns.pairplot(df);

# %%
sns.pairplot(df[df.comments != 0]);

# %%
df
# Out:
#       comments  blank_lines      code    config            lang  \
# 0            0            2  2.197225    travis         b'Java'
# 1            0            8  3.912023    travis       b'Python'
# 2            1            0  2.944439    travis   b'JavaScript'
# 3            0            8  3.332205  circleci   b'JavaScript'
# 4            0            6  4.905275    travis            b'C'
# ...        ...          ...       ...       ...             ...
# 6714         0            1  4.043051  circleci   b'JavaScript'
# 6715         0            1  3.610918    travis  b'Objective-C'
# 6716         0            1  1.791759    travis   b'JavaScript'
# 6717         0            8  4.330733    travis       b'Python'
# 6718         0            3  3.891820    github       b'Python'
#
#      yaml_encoding_error  code_with_comments  lines  percentage  stars  sub  \
# 0                    NaN                   0     11    0.000000   4039  128
# 1                    NaN                   1     57    0.000000   4039  118
# 2                    NaN                   0     19    5.263158   4039  163
# 3                    NaN                   0     36    0.000000   4039  163
# 4                    NaN                  36    105    0.000000   4038  233
# ...                  ...                 ...    ...         ...    ...  ...
# 6714                 NaN                   3     55    0.000000  10594  230
# 6715                 NaN                   0     38    0.000000   5850  115
# 6716                 NaN                   0      7    0.000000   3183   74
# 6717                 NaN                  10     74    0.000000   5849  272
# 6718                 NaN                   3     49    0.000000   5849  272
#
#                                                    data        id
# 0     bGFuZ3VhZ2U6IGphdmEKamRrOiBvcmFjbGVqZGs3CmVudj...  44498352
# 1     ZGlzdDogdHJ1c3R5CgpsYW5ndWFnZTogcHl0aG9uCgpjYW...   2337852
# 2     c3VkbzogZmFsc2UKbGFuZ3VhZ2U6IG5vZGVfanMKb3M6Ci...  66830040
# 3     dmFyXzE6ICZjYWNoZV9rZXkgc2FuLWRlcGVuZGVuY3ktY2...  66830040
# 4     bGFuZ3VhZ2U6IHN3aWZ0Cnhjb2RlX3dvcmtzcGFjZTogUH...  12416862
# ...                                                 ...       ...
# 6714  dmVyc2lvbjogMgpnZW5lcmFsOgogIGJyYW5jaGVzOgogIC...  37734226
# 6715  bGFuZ3VhZ2U6IG9iamVjdGl2ZS1jCm9zeF9pbWFnZTogeG...  24956772
# 6716  bGFuZ3VhZ2U6IG5vZGVfanMKbm9kZV9qczoKICAtIG5vZG...  28691440
# 6717  bGFuZ3VhZ2U6IHB5dGhvbgpjYWNoZTogcGlwCmRpc3Q6IH...   1446467
# 6718  bmFtZTogQ29kZSBxdWFsaXR5CgpvbjoKICBwdXNoOgogIH...   1446467
#
# [6719 rows x 13 columns]

# %%
import math
df.code = np.log(df.code)
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=test);
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-e0c6c0ac41f2> in <module>
#       2 df.code = np.log(df.code)
#       3 plt.figure(figsize=(8, 5))
# ----> 4 sns.regplot(x="code", y="comments", data=test);
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     779                                  order, logistic, lowess, robust, logx,
#     780                                  x_partial, y_partial, truncate, dropna,
# --> 781                                  x_jitter, y_jitter, color, label)
#     782
#     783     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in establish_variables(self, data, **kws)
#      46         for var, val in kws.items():
#      47             if isinstance(val, string_types):
# ---> 48                 setattr(self, var, data[val])
#      49             elif isinstance(val, list):
#      50                 setattr(self, var, np.asarray(val))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'code'

# %%
_temp = df[df.code.notnull()]
_temp
# Out:
#       comments  blank_lines      code    config            lang  \
# 0            0            2  0.787195    travis         b'Java'
# 1            0            8  1.364055    travis       b'Python'
# 2            1            0  1.079918    travis   b'JavaScript'
# 3            0            8  1.203634  circleci   b'JavaScript'
# 4            0            6  1.590311    travis            b'C'
# ...        ...          ...       ...       ...             ...
# 6714         0            1  1.397000  circleci   b'JavaScript'
# 6715         0            1  1.283962    travis  b'Objective-C'
# 6716         0            1  0.583198    travis   b'JavaScript'
# 6717         0            8  1.465737    travis       b'Python'
# 6718         0            3  1.358877    github       b'Python'
#
#      yaml_encoding_error  code_with_comments  lines  percentage  stars  sub  \
# 0                    NaN                   0     11    0.000000   4039  128
# 1                    NaN                   1     57    0.000000   4039  118
# 2                    NaN                   0     19    5.263158   4039  163
# 3                    NaN                   0     36    0.000000   4039  163
# 4                    NaN                  36    105    0.000000   4038  233
# ...                  ...                 ...    ...         ...    ...  ...
# 6714                 NaN                   3     55    0.000000  10594  230
# 6715                 NaN                   0     38    0.000000   5850  115
# 6716                 NaN                   0      7    0.000000   3183   74
# 6717                 NaN                  10     74    0.000000   5849  272
# 6718                 NaN                   3     49    0.000000   5849  272
#
#                                                    data        id
# 0     bGFuZ3VhZ2U6IGphdmEKamRrOiBvcmFjbGVqZGs3CmVudj...  44498352
# 1     ZGlzdDogdHJ1c3R5CgpsYW5ndWFnZTogcHl0aG9uCgpjYW...   2337852
# 2     c3VkbzogZmFsc2UKbGFuZ3VhZ2U6IG5vZGVfanMKb3M6Ci...  66830040
# 3     dmFyXzE6ICZjYWNoZV9rZXkgc2FuLWRlcGVuZGVuY3ktY2...  66830040
# 4     bGFuZ3VhZ2U6IHN3aWZ0Cnhjb2RlX3dvcmtzcGFjZTogUH...  12416862
# ...                                                 ...       ...
# 6714  dmVyc2lvbjogMgpnZW5lcmFsOgogIGJyYW5jaGVzOgogIC...  37734226
# 6715  bGFuZ3VhZ2U6IG9iamVjdGl2ZS1jCm9zeF9pbWFnZTogeG...  24956772
# 6716  bGFuZ3VhZ2U6IG5vZGVfanMKbm9kZV9qczoKICAtIG5vZG...  28691440
# 6717  bGFuZ3VhZ2U6IHB5dGhvbgpjYWNoZTogcGlwCmRpc3Q6IH...   1446467
# 6718  bmFtZTogQ29kZSBxdWFsaXR5CgpvbjoKICBwdXNoOgogIH...   1446467
#
# [6718 rows x 13 columns]

# %%
_temp.code = np.log2(_temp.code)

# %%
_temp
# Out:
#       comments  blank_lines      code    config            lang  \
# 0            0            2 -0.239279    travis         b'Java'
# 1            0            8  0.310462    travis       b'Python'
# 2            1            0  0.076885    travis   b'JavaScript'
# 3            0            8  0.185345  circleci   b'JavaScript'
# 4            0            6  0.463930    travis            b'C'
# ...        ...          ...       ...       ...             ...
# 6714         0            1  0.334327  circleci   b'JavaScript'
# 6715         0            1  0.249951    travis  b'Objective-C'
# 6716         0            1 -0.539228    travis   b'JavaScript'
# 6717         0            8  0.382358    travis       b'Python'
# 6718         0            3  0.306659    github       b'Python'
#
#      yaml_encoding_error  code_with_comments  lines  percentage  stars  sub  \
# 0                    NaN                   0     11    0.000000   4039  128
# 1                    NaN                   1     57    0.000000   4039  118
# 2                    NaN                   0     19    5.263158   4039  163
# 3                    NaN                   0     36    0.000000   4039  163
# 4                    NaN                  36    105    0.000000   4038  233
# ...                  ...                 ...    ...         ...    ...  ...
# 6714                 NaN                   3     55    0.000000  10594  230
# 6715                 NaN                   0     38    0.000000   5850  115
# 6716                 NaN                   0      7    0.000000   3183   74
# 6717                 NaN                  10     74    0.000000   5849  272
# 6718                 NaN                   3     49    0.000000   5849  272
#
#                                                    data        id
# 0     bGFuZ3VhZ2U6IGphdmEKamRrOiBvcmFjbGVqZGs3CmVudj...  44498352
# 1     ZGlzdDogdHJ1c3R5CgpsYW5ndWFnZTogcHl0aG9uCgpjYW...   2337852
# 2     c3VkbzogZmFsc2UKbGFuZ3VhZ2U6IG5vZGVfanMKb3M6Ci...  66830040
# 3     dmFyXzE6ICZjYWNoZV9rZXkgc2FuLWRlcGVuZGVuY3ktY2...  66830040
# 4     bGFuZ3VhZ2U6IHN3aWZ0Cnhjb2RlX3dvcmtzcGFjZTogUH...  12416862
# ...                                                 ...       ...
# 6714  dmVyc2lvbjogMgpnZW5lcmFsOgogIGJyYW5jaGVzOgogIC...  37734226
# 6715  bGFuZ3VhZ2U6IG9iamVjdGl2ZS1jCm9zeF9pbWFnZTogeG...  24956772
# 6716  bGFuZ3VhZ2U6IG5vZGVfanMKbm9kZV9qczoKICAtIG5vZG...  28691440
# 6717  bGFuZ3VhZ2U6IHB5dGhvbgpjYWNoZTogcGlwCmRpc3Q6IH...   1446467
# 6718  bmFtZTogQ29kZSBxdWFsaXR5CgpvbjoKICBwdXNoOgogIH...   1446467
#
# [6718 rows x 13 columns]

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x="code", y="comments", data=_temp);

# %%
def log(data, column, y):
    _data = data[data[column].notnull()]
    _data[column] = np.log2(_data[column])
    return sns.regplot(x=column, y=y, data=_data)

# %%
log(df, "code", "blank_lines")
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
log(df, "stars", "sub")

# %%
df.columns
# Out:
# Index(['comments', 'blank_lines', 'code', 'config', 'lang',
#        'yaml_encoding_error', 'code_with_comments', 'lines', 'percentage',
#        'stars', 'sub', 'data', 'id'],
#       dtype='object')

# %%
log(df[df.comments != 0], "comments", "code_with_comments")

# %%
log(df[df.comments != 0], "code_with_comments", "comments")
